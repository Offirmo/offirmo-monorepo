// %% [markdown]
// # [storage API](https://developer.mozilla.org/en-US/docs/Web/API/Web_Crypto_API)

// %% [markdown]
// ## localStorage

// %%
localStorage.setItem('foo', 'local42')

// %%
localStorage.getItem('foo')

// %% [markdown]
// (restart the kernel here)

// %%
localStorage.getItem('foo')

// %% [markdown]
// ## sessionStorage

// %%
sessionStorage.setItem('foo', 'session42')

// %%
sessionStorage.getItem('foo')

// %% [markdown]
// (restart the kernel here)

// %%
sessionStorage.getItem('foo')
