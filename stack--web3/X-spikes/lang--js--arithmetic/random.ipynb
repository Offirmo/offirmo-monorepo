// %% [markdown]
// # random gen

// %% [markdown]
// ## Hex string

// %%
function randomHex(bytes = 16) {
  return crypto.getRandomValues(new Uint8Array(bytes))
    .reduce((str, b) => str + b.toString(16).padStart(2, "0"), "");
}

// Example: 32-char hex string
randomHex(8);
