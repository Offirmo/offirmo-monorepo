// %% [markdown]
// # int arithmetic

// %% [markdown]
// ## rounding to closest acceptable representation
//
// https://devdocs.io/javascript/global_objects/json/rawjson

// %%
12345678901234567890

// %%
JSON.stringify({ value: 12345678901234567890 });

// %%
const rawJSON = JSON.rawJSON("12345678901234567890");
JSON.stringify({ value: rawJSON });

// %% [markdown]
// ## BigInt
