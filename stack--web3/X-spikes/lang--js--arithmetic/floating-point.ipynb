// %% [markdown]
// # numbers
//
// https://0.30000000000000004.com/

// %%
.1 + .2
// Out:
// 0.30000000000000004

// %%
const n = 1.01
n
// Out:
// 1.01

// %%
n * 2
// Out:
// 2.02

// %%
n * 3
// Out:
// 3.0300000000000002

// %%
n * 4
// Out:
// 4.04

// %%
n * 5
// Out:
// 5.05

// %%
n * 6
// Out:
// 6.0600000000000005
