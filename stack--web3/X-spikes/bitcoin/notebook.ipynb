// %% [markdown]
// # Bitcoin
//
// https://learnmeabitcoin.com/beginners/how-does-bitcoin-work/

// %% [markdown]
// ## keys
//
// 1. generation using [`@scure/bip39`](https://github.com/paulmillr/scure-bip39)
// 2. derivation using ...

// %%
import * as bip39 from "npm:@scure/bip39";
import { wordlist } from "npm:@scure/bip39/wordlists/english.js";
const SEED_PHRASE = bip39.generateMnemonic(wordlist, 24);

// %%
console.log(SEED_PHRASE)
bip39.validateMnemonic(SEED_PHRASE, wordlist);

// %% [markdown]
// ## Config
//
// 1. network
